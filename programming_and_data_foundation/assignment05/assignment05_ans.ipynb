# %% [markdown]
# ##### -------------------------------------------------------------------------------------------

# %% [markdown]
# ### GEN AI WE PROGRAM [ Programming and Data Foundation ]
# ### ASSIGNMENT 05
# #### Suyog Yadav ( 20546756 )

# %% [markdown]
# ##### -------------------------------------------------------------------------------------------

# %% [markdown]
# Import Pandas as PD

# %%
# importing pandas as pd

import pandas as pd

# %% [markdown]
# ##### -------------------------------------------------------------------------------------------

# %% [markdown]
# Read Salaries.csv as a dataframe called sal.

# %%
sal = pd.read_csv("Salaries.csv")

# %% [markdown]
# ##### -------------------------------------------------------------------------------------------

# %% [markdown]
# Check the head of the DataFrame.

# %%
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency
# 0  2011    NaN  San Francisco
# ...

# %% [markdown]
# ##### -------------------------------------------------------------------------------------------

# %% [markdown]
# Use the .info() method to find out how many entries there are.

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                79 non-null     int64
#  1   EmployeeName      79 non-null     object
#  2   JobTitle          79 non-null     object
#  3   BasePay           79 non-null     float64
#  4   OvertimePay       79 non-null     float64
#  5   OtherPay          79 non-null     float64
#  6   Benefits          0 non-null      float64
#  7   TotalPay          79 non-null     float64
#  8   TotalPayBenefits  79 non-null     float64
#  9   Year              79 non-null     int64
#  10  Notes             0 non-null      float64
#  11  Agency            79 non-null     object
# dtypes: float64(7), int64(2), object(3)
# memory usage: 7.5+ KB

# %% [markdown]
# ##### -------------------------------------------------------------------------------------------

# %% [markdown]
# What is the average BasePay ?

# %%
avg_base_pay = sal['BasePay'].mean()
print(avg_base_pay)
# Out:
# 176365.55113924053

# %% [markdown]
# ##### -------------------------------------------------------------------------------------------

# %% [markdown]
# What is the highest amount of OvertimePay in the dataset ?

# %%
highest_overtimepay = sal['OvertimePay'].max()
print(highest_overtimepay)
# Out:
# 245131.88

# %% [markdown]
# ##### -------------------------------------------------------------------------------------------

# %% [markdown]
# What is the job title of JOSEPH DRISCOLL ? Note: Use all caps, otherwise you may getan answer that doesn't match up (there is also a lowercase Joseph Driscoll).

# %%
sal[sal['EmployeeName'] == 'JOSEPH DRISCOLL']['JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %% [markdown]
# ##### -------------------------------------------------------------------------------------------

# %% [markdown]
# How much does JOSEPH DRISCOLL make (including benefits)?

# %%
sal[sal['EmployeeName'] == 'JOSEPH DRISCOLL']['TotalPayBenefits']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# ##### -------------------------------------------------------------------------------------------

# %% [markdown]
# What is the name of highest paid person (including benefits)?

# %%
sal.loc[sal['TotalPayBenefits'].idxmax()]
# Out:
# Id                                                               1
# EmployeeName                                        NATHANIEL FORD
# JobTitle            GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# BasePay                                                  167411.18
# OvertimePay                                                    0.0
# OtherPay                                                 400184.25
# Benefits                                                       NaN
# TotalPay                                                 567595.43
# TotalPayBenefits                                         567595.43
# Year                                                          2011
# Notes                                                          NaN
# Agency                                               San Francisco
# Name: 0, dtype: object

# %% [markdown]
# ##### -------------------------------------------------------------------------------------------

# %% [markdown]
# What is the name of lowest paid person (including benefits)? Do you notice somethingstrange about how much he or she is paid?

# %%
sal.loc[sal['TotalPayBenefits'].idxmin()]
# Out:
# Id                                         79
# EmployeeName                   MICHAEL DELANE
# JobTitle            CAPTAIN, FIRE SUPPRESSION
# BasePay                             140546.88
# OvertimePay                           62283.7
# OtherPay                             28821.55
# Benefits                                  NaN
# TotalPay                            231652.13
# TotalPayBenefits                    231652.13
# Year                                     2011
# Notes                                     NaN
# Agency                          San Francisco
# Name: 78, dtype: object

# %% [markdown]
# ##### -------------------------------------------------------------------------------------------

# %% [markdown]
# What was the average (mean) BasePay of all employees per year? (2011-2014) ?

# %%
sal.groupby('Year')['BasePay'].mean()
# Out:
# Year
# 2011    176365.551139
# Name: BasePay, dtype: float64

# %% [markdown]
# ##### -------------------------------------------------------------------------------------------

# %% [markdown]
# How many unique job titles are there?

# %%
sal['JobTitle'].nunique()
# Out:
# 31

# %% [markdown]
# ##### -------------------------------------------------------------------------------------------

# %% [markdown]
# What are the top 5 most common jobs?

# %%
sal['JobTitle'].value_counts().head(5)
# Out:
# JobTitle
# BATTALION CHIEF, (FIRE DEPARTMENT)      15
# CAPTAIN, FIRE SUPPRESSION                7
# DEPARTMENT HEAD V                        6
# DEPUTY CHIEF III (POLICE DEPARTMENT)     5
# CAPTAIN III (POLICE DEPARTMENT)          5
# Name: count, dtype: int64

# %% [markdown]
# ##### -------------------------------------------------------------------------------------------

# %% [markdown]
# How many Job Titles were represented by only one person in 2011? (e.g. Job Titleswith only one occurence in 2011?)

# %%
sum(sal[sal['Year'] == 2011]
    ['JobTitle'].value_counts() == 1)
# Out:
# 16

# %% [markdown]
# ##### -------------------------------------------------------------------------------------------
